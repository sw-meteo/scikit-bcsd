# %%
import xarray as xr

# %%
ds_model = xr.open_dataset('../data/cmip/pre-ACCESS-ESM1-5-historical-1850-2014.nc')
ds_model
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 1980, lon: 192, lat: 145)
# Coordinates:
#   * time     (time) datetime64[ns] 1850-01-16T12:00:00 ... 2014-12-16T12:00:00
#   * lon      (lon) float64 0.0 1.875 3.75 5.625 7.5 ... 352.5 354.4 356.2 358.1
#   * lat      (lat) float64 -90.0 -88.75 -87.5 -86.25 ... 86.25 87.5 88.75 90.0
# Data variables:
#     pre      (time, lat, lon) float32 ...
# Attributes:
#     CDI:          Climate Data Interface version 2.0.3 (https://mpimet.mpg.de...
#     Conventions:  CF-1.6
#     CDO:          Climate Data Operators version 2.0.3 (https://mpimet.mpg.de...
#     NCO:          netCDF Operators version 5.1.0 (Homepage = http://nco.sf.ne...
#     history:      Sun Sep 29 20:57:36 2024: ncatted -O -a comment1,global,d,,...

# %%
ds_model.isel(time=1000).pre.plot()

# %%
ds_obs = xr.open_dataset('../data/obs/pre-GPCC-1901-2020.nc')
ds_obs
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 1440, lon: 720, lat: 360)
# Coordinates:
#   * time     (time) datetime64[ns] 1901-01-16 1901-02-15 ... 2020-12-16
#   * lon      (lon) float64 -179.8 -179.2 -178.8 -178.2 ... 178.8 179.2 179.8
#   * lat      (lat) float64 -89.75 -89.25 -88.75 -88.25 ... 88.75 89.25 89.75
# Data variables:
#     pre      (time, lat, lon) float32 ...
# Attributes:
#     CDI:          Climate Data Interface version 2.0.3 (https://mpimet.mpg.de...
#     Conventions:  CF-1.6
#     CDO:          Climate Data Operators version 2.0.3 (https://mpimet.mpg.de...
#     history:      Sun Sep 29 20:58:16 2024: ncatted -O -a comment1,global,d,,...
#     NCO:          netCDF Operators version 5.1.0 (Homepage = http://nco.sf.ne...

# %%
ds_obs.isel(time=1000).pre.plot()
