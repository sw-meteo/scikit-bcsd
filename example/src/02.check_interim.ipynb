# %%
import xarray as xr

# %%
ds_model = xr.open_dataset('../interim/pre.ACCESS-ESM1-5.1901-2014.nc')
ds_model
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 1368, lat: 145, lon: 192)
# Coordinates:
#   * time     (time) datetime64[ns] 1901-01-01 1901-02-01 ... 2014-12-01
#   * lat      (lat) float64 -90.0 -88.75 -87.5 -86.25 ... 86.25 87.5 88.75 90.0
#   * lon      (lon) float64 -180.0 -178.1 -176.2 -174.4 ... 174.4 176.2 178.1
# Data variables:
#     pre      (time, lat, lon) float32 ...

# %%
ds_model.isel(time=1000).pre.plot()

# %%
ds_model_valid_grid = xr.open_dataset('../interim/pre.valid_grid.GPCC.on.ACCESS-ESM1-5.nc')
ds_model_valid_grid
# Out:
# <xarray.Dataset>
# Dimensions:     (lat: 145, lon: 192)
# Coordinates:
#   * lat         (lat) float64 -90.0 -88.75 -87.5 -86.25 ... 87.5 88.75 90.0
#   * lon         (lon) float64 -180.0 -178.1 -176.2 -174.4 ... 174.4 176.2 178.1
# Data variables:
#     valid_grid  (lat, lon) bool ...

# %%
ds_model_valid_grid.valid_grid.plot()

# %%
ds_obs = xr.open_dataset("../interim/pre.GPCC.1901-2014.nc")
ds_obs
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 1368, lat: 360, lon: 720)
# Coordinates:
#   * time     (time) datetime64[ns] 1901-01-01 1901-02-01 ... 2014-12-01
#   * lat      (lat) float64 -89.75 -89.25 -88.75 -88.25 ... 88.75 89.25 89.75
#   * lon      (lon) float64 -179.8 -179.2 -178.8 -178.2 ... 178.8 179.2 179.8
# Data variables:
#     pre      (time, lat, lon) float32 ...

# %%
ds_obs.isel(time=1000).pre.plot()

# %%
ds_obs_valid_grid = xr.open_dataset('../interim/pre.valid_grid.GPCC.nc')
ds_obs_valid_grid
# Out:
# <xarray.Dataset>
# Dimensions:     (lon: 720, lat: 360)
# Coordinates:
#   * lon         (lon) float64 -179.8 -179.2 -178.8 -178.2 ... 178.8 179.2 179.8
#   * lat         (lat) float64 -89.75 -89.25 -88.75 -88.25 ... 88.75 89.25 89.75
# Data variables:
#     valid_grid  (lat, lon) bool ...

# %%
ds_obs_valid_grid.valid_grid.plot()
