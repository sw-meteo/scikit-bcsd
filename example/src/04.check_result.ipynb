# %%
import xarray as xr

# %%
ds_model = xr.open_dataset('../result/pre.ACCESS-ESM1-5.1901-1920.bcsd.nc')
ds_model
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 240, lat: 360, lon: 720)
# Coordinates:
#   * lat      (lat) float64 -89.75 -89.25 -88.75 -88.25 ... 88.75 89.25 89.75
#   * lon      (lon) float64 -179.8 -179.2 -178.8 -178.2 ... 178.8 179.2 179.8
#   * time     (time) datetime64[ns] 1901-01-01 1901-02-01 ... 1920-12-01
# Data variables:
#     pre      (time, lat, lon) float32 ...

# %%
ds_model.isel(time=100).pre.plot(vmin=0, vmax=200)
